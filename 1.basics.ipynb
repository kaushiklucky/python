# %% [markdown]
# # Introduction of Python

# %% [markdown]
# ## Introduction of Python

# %% [markdown]
# ### Introduction of Python

# %% [markdown]
# #### Introduction of Python

# %% [raw]
# Programming language :- A programming language is a formal languagefor creating instruction for a computer
#
# - Set of rules and symboles that defines the process of writing computer program
#
# Why do we study programming languages?
# -interation with computer
# -software program
# -Embedded device
# -Robotics
#
# Why python?
# -widely used in the indusrty
# -A lot of libraries
# -versatlity - web dev, frontend, backend, ML, data analyas, databases
# - Automation, image processing
# -Easy to learn
# -Huge active community
#
#
# IDEs - Integrated Development Environment software
# -VScode, pycham, googlecolab

# %%
print("Namaste Duniya")
# Out:
# Namaste Duniya

# %%
a = 3

# %%
a
# Out:
# 3

# %% [raw]
# Variables/identifiers >>placeholders where we keep variety of data which we can use to write logic
# #Numbers>> integers/float
# #characters>> string in python
# #True/False >> boolean
# #None
# #complex

# %%
b=4
b
# Out:
# 4

# %%
#variable is a reserved memory space for storing value

# %%
b = 4.5
b
# Out:
# 4.5

# %%
#a memory space will be created with value of the variable

# %%
c = "Lucky"
c
# Out:
# 'Lucky'

# %%
type(c)
# Out:
# str

# %%
a = 3
a
# Out:
# 3

# %%
type(a)
# Out:
# int

# %%
b = 4.5
type(b)
# Out:
# float

# %%
c = True
type(c)
# Out:
# bool

# %%
d = False
type(d)
# Out:
# bool

# %%
True-False
# Out:
# 1

# %%
True * False
# Out:
# 0

# %%
#True/False>> it will throw an error

# %%
f = None
f

# %%
type(f)
# Out:
# NoneType

# %%
#x+iy>> complex number

# %%
com = 5+6j

# %%
type(com)
# Out:
# complex

# %%
com.real
# Out:
# 5.0

# %%
com.imag
# Out:
# 6.0

# %%
#Rules of defining a variable>> A variable start with a letter(alphabet) or underscore character, it should not be keyword

# %% [raw]
# invalid ways
# 5 = a
# 2.3 = b
# 1name = "Ram"
# 1 = abc

# %%
# Valid ways
name = "Kaushik"
name
# Out:
# 'Kaushik'

# %%
location = "mumbai"
location
# Out:
# 'mumbai'

# %%
_name = "Rahul"
_name
# Out:
# 'Rahul'

# %%
data_science = "pwskills"
data_science
# Out:
# 'pwskills'

# %%
#This is my first line of comment
#This is my second line of comment

# %%
#Multiline comments >> this are also called as doc string or document string
'''
This is a multi line comments
I am teaching ds
all the students are enjoying
'''
# Out:
# '\nThis is a multi line comments\nI am teaching ds\nall the students are enjoying\n'

# %%
#keywords >> are predefined words that hold a special meaning and have specific purpose in python

# %%
help('keywords')
# Out:
# Here is a list of the Python keywords.  Enter any keyword to get more help.
#
# False               class               from                or
# None                continue            global              pass
# True                def                 if                  raise
# and                 del                 import              return
# as                  elif                in                  try
# assert              else                is                  while
# async               except              lambda              with
# await               finally             nonlocal            yield
# break               for                 not

# %%
#Indentation>> more readble
if 3 > 2:
    print("greater")
# Out:
# greater

# %%
a = 3 #statement >> fundamental block of code
name = "Lucky"

#statment can be of many tiypes>> expression, assignment, condition statments, loop

# %%
#assignment statement
a = 5

# %%
a = 5 #assignment
b = 4 #assignment
a+b #expression statment
# Out:
# 9

# %%
#input output>>if you want some user to give value of variable
name = input("please enter your name: ")
print(name)
# Out:
# Lucky kaushik

# %%
type(name)
# Out:
# str

# %%
name1 = input("please enter your name: ")
print(name1)
# Out:
# 2

# %%
type(name1)
# Out:
# str

# %%
#input actualy take every value as a 
#we can convert '2' as int

# %%
name1
# Out:
# '2'

# %%
#type casting >> cast means to change the formate
int(name1)
# Out:
# 2

# %%
a = 6

# %%
a #In the memory, a memory block is created with reference name a and value 6
# Out:
# 6

# %%
b = "Lucky"

# %%
b #in memory block the indices are like 'L'->0, 'u'->1, 'c'->2, 'k'->3, 'y'->4.   Also in negtive indices 'L'-> -5, 'u'-> -4, 'c'-> -3, 'k'-> -2, 'y'-> -1.
# Out:
# 'Lucky'

# %%
#means 'L'->0,-5, 'u'->1,-4, 'c'->2,-3, 'k'->3,-2, 'y'->4,-1.

# %%
b[0]
# Out:
# 'L'

# %%
b[2]
# Out:
# 'c'

# %%
#Another type of data cointainer
List_cont = [1, 2, 3, 4.3, 3+5j, True, "Lucky"]

# %%
List_cont
# Out:
# [1, 2, 3, 4.3, (3+5j), True, 'Lucky']

# %%
List_cont[0]
# Out:
# 1

# %%
List_cont[4]
# Out:
# (3+5j)

# %%
List_cont[-4]
# Out:
# 4.3

# %%
name.upper()
# Out:
# 'LUCKY KAUSHIK'

# %%
name.lower()
# Out:
# 'lucky kaushik'

# %%
name.capitalize()
# Out:
# 'Lucky kaushik'

# %%
name.title()
# Out:
# 'Lucky Kaushik'

# %%
"Hello World!".swapcase()
# Out:
# 'hELLO wORLD!'

# %%
"Hello World!".count("l")
# Out:
# 3

# %%
name.count("k")
# Out:
# 3

# %%
name.replace("L", "D")
# Out:
# 'Ducky kaushik'

# %%
# An f-string (formatted string literal) is a way to embed expressions inside string literals, using {} curly braces.
name = "Lucky"
age = 18
print(f"My name is {name} and I am {age} years old.")
# Out:
# My name is Lucky and I am 18 years old.
