# %%
a = 5
a
# Out:
# 5

# %%
type(a)
# Out:
# int

# %%
b = 5.6
b
# Out:
# 5.6

# %%
type(b)
# Out:
# float

# %%
c = "Lucky"
c
# Out:
# 'Lucky'

# %%
type(c)
# Out:
# str

# %%
# "2"+3 >> thiscan't be added bcos 2 is string and 3 is integer

# %%
# type casting/type conversion >> the process of changing the data type of a value/object
#why? >> while excuting /computation using operator, ther can be mismatch between the data types

# %%
# a = "2"
# b = 3
# a+b throgth error

# %%
a = "2"
b = 3
int(a)+b
# Out:
# 5

# %%
#string to integer
a = "2"
print(type(a))
print(type(int(a)))
# Out:
# <class 'str'>
# <class 'int'>

# %%
a = 3.4
b = 5
a+b  # float and int can be added
# Out:
# 8.4

# %%
#float to integer
a = 3.4
print(type(a))
float_value = int(a)
print(type(float_value))
float_value
# Out:
# <class 'float'>
# <class 'int'>
# 3

# %%
#integer to float
c = 5
print(type(c))
int_value = float(c)
print(type(int_value))
int_value
# Out:
# <class 'int'>
# <class 'float'>
# 5.0

# %%
#string to float
a = "2.3"
type(a)
# Out:
# str

# %%
a
# Out:
# '2.3'

# %%
b = float(a)
type(b)
# Out:
# float

# %%
b
# Out:
# 2.3

# %%
#integer to string
a = 5
type(a)
# Out:
# int

# %%
a
# Out:
# 5

# %%
c = str(a)
c
# Out:
# '5'

# %%
type(c)
# Out:
# str

# %%
#string/character can't convered into int/float/numbers

# %%
#typecasting >> implicit and explicit

# %%
#implicit typecasting >> python understand the datatype. unlike c, c++, java there we have to define the data type
a = 5
type(a)
# Out:
# int

# %%
2+3
# Out:
# 5

# %%
2+3.5
# Out:
# 5.5

# %%
#explicit typecasting >> convert data type using inbuilt function >> str, int, float, bool
a = '2'
type(a)
# Out:
# str

# %%
int(a)
# Out:
# 2

# %%
float(a)
# Out:
# 2.0

# %%
#concatenation
a = "Lucky"
b = "Kaushik"
a+b
# Out:
# 'LuckyKaushik'

# %%
a = "3"
b = "4"
a+b
# Out:
# '34'

# %%
a = "Lucky"
b = " 4 "
c = "u"
a+b+c
# Out:
# 'Lucky 4 u'

# %%
#bool
bool(0)
# Out:
# False

# %%
bool(1)
# Out:
# True

# %%
bool(2)
# Out:
# True

# %%
bool(10)
# Out:
# True

# %%
bool("Lucky")
# Out:
# True

# %%
bool("") #empty string
# Out:
# False

# %%
bool(-5)
# Out:
# True

# %%
num = "100"         # string
num_int = int(num)  # convert to integer
print(num_int + 20) # 120
# Out:
# 120
