# %%
#pip install bokeh

# %%
import bokeh.io
import bokeh.plotting
bokeh.io.output_notebook()
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="f036d775-f807-41af-811d-0eddde6999ae">Loading BokehJS ...</span>
#     </div>

# %%
from bokeh.sampledata.iris import flowers
from bokeh.plotting import figure, output_file, show

# %%
flowers
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
output_file("test.html")
p = figure(title = 'test_flower')
p.xaxis.axis_label = "petal_length"
p.yaxis.axis_label = "petal_width"
p.scatter(flowers['petal_length'], flowers['petal_width']) #circle for scatter plot
show(p)
# Out:
#   <div id="bdc2d2d6-e82d-4426-a326-e0b4812ee20b" data-root-id="p1185" style="display: contents;"></div>

# %%
output_file("test.html")
p = figure(title = 'test_flower')
p.xaxis.axis_label = "petal_length"
p.yaxis.axis_label = "petal_width"
p.line(flowers['petal_length'], flowers['petal_width']) #line for line chart
show(p)
# Out:
#   <div id="bbb254bf-7bd6-42c4-879a-20ea76a60ed9" data-root-id="p1139" style="display: contents;"></div>

# %%
x = [1,2,3,4]
y = [3,8,4,7]

p = figure(title="line_chat")
p.line(x,y)
show(p)
# Out:
#   <div id="d86f2111-bdf3-4351-9ea0-3dd5c90ccdd3" data-root-id="p1231" style="display: contents;"></div>

# %%
x = [1,2,3,4]
y = [3,8,4,7]

p = figure(title="line_chat")
p.scatter(x,y, size=20, fill_color='red', legend_label="This is my data")
show(p)
# Out:
#   <div id="e9f28188-d2d0-47f2-8a8e-f37aef8a5e78" data-root-id="p1357" style="display: contents;"></div>
